# %% [markdown]
# #                                           McDonald's  Dataset Analysis

# %% [markdown]
# #  Summary

# %% [markdown]
# Following is a Case Study which is done for the purpose of Analysis of data and its visualization on a selected Dataset.
# The McDonalds Dataset has been selected for the Data Analysis & its visualization.
# The Dataset consists of details of different categories of food items & their nutritional value.
# The Analysis of this Dataset is done in Python & using necessary Python Libraries and Tools.
# This Report has been prepared in a simple & easy to read, understand manner for reviewer.
# All insights are present right below the code which highlights necessary information about code and graphs which makes it more interesting to read.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing & Loading Dataset

# %%
df=pd.read_csv("menu.csv")

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# # Displaying all columns in given dataset

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %% [markdown]
# # Checking for null values in dataset

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# Above dataset has no missing values

# %%
df.describe().T
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %% [markdown]
# # Q1. Display different categories of food having highest and lowest varieties and plot it graphically

# %%
df["Category"].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(14,10))
plt.title("Food Categories")
sns.countplot(x="Category",data=df)
plt.xlabel("categories")
plt.ylabel("count")
plt.grid()
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# From the above graph it can be concluded that
#
# 1) The highest sales is of Tea & Coffee
#
# 2) The lowest sales is of Salads & Desserts

# %%
df.corr()
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %% [markdown]
# # Q2. Create a pie chart that shows proportions of each cateogry of food

# %%
plt.figure(figsize=(8,9))
plt.title("Category %")
df["Category"].value_counts().plot(kind="pie",autopct="% 1.2f%%",explode=(0.09,0,0,0,0,0,0,0.09,0.09))
plt.show()

# %% [markdown]
# # Q3. Display Category of food having maximum amount of cholesterol and plot graph for same.

# %%
max_cholestrol=df["Cholesterol"].max()
df[df["Cholesterol"]==max_cholestrol]
# Out:
#      Category                                           Item     Serving Size  \
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)  15.3 oz (434 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 31      1090                510       56.0                         87
# 32      1150                540       60.0                         93
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 31           19.0                             96        0.0  ...
# 32           20.0                            100        0.0  ...
#
#     Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 31            111                             37              6
# 32            116                             39              7
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %% [markdown]
# # Q4. Draw a graph Cholesterol Vs Food Categories

# %%
plt.figure(figsize=(10,8))
df.pivot_table('Cholesterol','Category').plot(kind='bar')
plt.show()

# %% [markdown]
# # Q5. Display top 10 Smoothies & Shakes having high calories ?

# %%
ss=df[df["Category"] == "Smoothies & Shakes"]
ss[["Item", "Calories"]].sort_values("Calories",ascending=False).head(10)
# Out:
#                                                   Item  Calories
# 253               McFlurry with M&M’s Candies (Medium)       930
# 246                           Strawberry Shake (Large)       850
# 249                            Chocolate Shake (Large)       850
# 243                              Vanilla Shake (Large)       820
# 251                             Shamrock Shake (Large)       820
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)       810
# 248                           Chocolate Shake (Medium)       700
# 256                McFlurry with Oreo Cookies (Medium)       690
# 245                          Strawberry Shake (Medium)       690
# 242                             Vanilla Shake (Medium)       660

# %% [markdown]
# # Q6. What is the mean (average) calorie count of each category?

# %%
cal_grp=df.groupby(by="Category")
cal_grp["Calories"].mean()
# Out:
# Category
# Beef & Pork           494.000000
# Beverages             113.703704
# Breakfast             526.666667
# Chicken & Fish        552.962963
# Coffee & Tea          283.894737
# Desserts              222.142857
# Salads                270.000000
# Smoothies & Shakes    531.428571
# Snacks & Sides        245.769231
# Name: Calories, dtype: float64

# %%
plt.figure(figsize=(7,6))
plt.title("Calorie Count")
cal_grp["Calories"].mean().plot(kind="bar",color="cyan")
plt.ylabel("Average")
plt.show()

# %% [markdown]
# # Q7. Check for item which contains no sugar.

# %%
x=df[df["Sugars"]==0]
x[["Sugars","Category","Item"]].head()
# Out:
#     Sugars        Category                          Item
# 38       0       Breakfast                    Hash Brown
# 78       0  Chicken & Fish   Chicken McNuggets (4 piece)
# 79       0  Chicken & Fish   Chicken McNuggets (6 piece)
# 80       0  Chicken & Fish  Chicken McNuggets (10 piece)
# 81       0  Chicken & Fish  Chicken McNuggets (20 piece)

# %% [markdown]
# # Q8. Display top 5 Item which contributes maximum amount of Proteins in a diet.

# %%
max_protein=df[df["Category"] == df["Category"]]
max_protein[["Item","Category","Protein"]].sort_values("Protein",ascending=False).head(5)
# Out:
#                                         Item        Category  Protein
# 82              Chicken McNuggets (40 piece)  Chicken & Fish       87
# 47        Double Quarter Pounder with Cheese     Beef & Pork       48
# 81              Chicken McNuggets (20 piece)  Chicken & Fish       44
# 60     Premium Grilled Chicken Club Sandwich  Chicken & Fish       40
# 64  Bacon Clubhouse Grilled Chicken Sandwich  Chicken & Fish       40

# %% [markdown]
# # Q9. Display all food items having Total Fat greater than 45.

# %%
Total_Fat=df[df["Total Fat"]>=45]

# %%
Total_Fat[["Category","Item","Total Fat"]]
# Out:
#           Category                                               Item  \
# 27       Breakfast                    Big Breakfast (Regular Biscuit)
# 28       Breakfast                      Big Breakfast (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 81  Chicken & Fish                       Chicken McNuggets (20 piece)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#     Total Fat
# 27       48.0
# 28       52.0
# 31       56.0
# 32       60.0
# 33       46.0
# 34       50.0
# 81       59.0
# 82      118.0

# %% [markdown]
# # Q10. Display all food items ranging Vitamin C (% Daily Value) between 70 to 200

# %%
vit_C=df[(df["Vitamin C (% Daily Value)"]>=70)&(df["Vitamin C (% Daily Value)"]<=200)]

# %%
vit_C[["Category","Item","Vitamin C (% Daily Value)"]].sort_values("Vitamin C (% Daily Value)",ascending=False)
# Out:
#            Category                                       Item  \
# 101  Snacks & Sides                               Apple Slices
# 134       Beverages          Minute Maid Orange Juice (Medium)
# 40        Breakfast                      Fruit & Maple Oatmeal
# 41        Breakfast  Fruit & Maple Oatmeal without Brown Sugar
# 133       Beverages           Minute Maid Orange Juice (Small)
# 132       Beverages           Minute Maid 100% Apple Juice Box
# 98   Snacks & Sides                         Large French Fries
#
#      Vitamin C (% Daily Value)
# 101                        160
# 134                        160
# 40                         130
# 41                         130
# 133                        130
# 132                        100
# 98                          70
